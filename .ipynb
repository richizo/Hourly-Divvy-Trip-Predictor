# %%
import pandas as pd 

inference_data = pd.read_parquet("/home/kobina/ML/Projects/Divvy-Bikes-Demand-Predictor/data/transformed/inference/starts.parquet")
training_data = pd.read_parquet("/home/kobina/ML/Projects/Divvy-Bikes-Demand-Predictor/data/transformed/training data/starts.parquet")

# %%
inference_data
# Out:
#       trips_previous_672_hour  trips_previous_671_hour  \
# 0                         1.0                      1.0
# 1                         1.0                      1.0
# 2                         1.0                      3.0
# 3                         1.0                      2.0
# 4                         2.0                      1.0
# ...                       ...                      ...
# 8691                      1.0                      1.0
# 8692                      1.0                      1.0
# 8693                      1.0                      1.0
# 8694                      1.0                      1.0
# 8695                      1.0                      1.0
#
#       trips_previous_670_hour  trips_previous_669_hour  \
# 0                         3.0                      2.0
# 1                         1.0                      1.0
# 2                         5.0                      3.0
# 3                         3.0                      4.0
# ...

# %%
[col for col in training_data.columns if col not in inference_data.columns]
# Out:
# []

# %%
# Out:
# ['start_station_id',
#  'hour',
#  'day_of_the_week',
#  'average_trips_last_4_weeks',
#  'trips_next_hour']

# %%
start_data = pd.read_parquet("/home/kobina/ML/Projects/Divvy-Bikes-Demand-Predictor/data/transformed/training data/ends.parquet")

# %%
start_data
# Out:
#        trips_previous_672_hour  trips_previous_671_hour  \
# 0                          1.0                      2.0
# 1                          1.0                      1.0
# 2                          1.0                      1.0
# 3                          1.0                      1.0
# 4                          1.0                      1.0
# ...                        ...                      ...
# 10373                      1.0                      1.0
# 10374                      1.0                      1.0
# 10375                      2.0                      2.0
# 10376                      1.0                      1.0
# 10377                      1.0                      1.0
#
#        trips_previous_670_hour  trips_previous_669_hour  \
# 0                          2.0                      3.0
# 1                          1.0                      2.0
# 2                          1.0                      4.0
# 3                          1.0                      1.0
# ...

# %%
inference_data.shape
# Out:
# (8751, 677)

# %%
inference_data.columns[-4:]
# Out:
# Index(['hour', 'day_of_the_week', 'average_trips_last_4_weeks',
#        'trips_next_hour'],
#       dtype='object')
